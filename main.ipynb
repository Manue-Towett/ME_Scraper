# %%
import requests
# from bs4 import BeautifulSoup
from selenium import webdriver

# from twocaptcha import TwoCaptcha
from urllib.parse import urlparse, parse_qs
from selenium.webdriver.chrome.service import Service

USER = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "en-US,en;q=0.9",
    "Cache-Control": "max-age=0","Dnt": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Site": "same-origin",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

session = requests.Session()

response = session.get("https://manager.threecolts.com",
                       headers=headers)

response = session.get("https://manager.threecolts.com/v2/login", headers=headers)

with open("login.html", "w", encoding="utf-8") as f:
    f.write(response.text)

options = webdriver.ChromeOptions()

options.add_argument("--disable-infobars")

options.add_argument('--no-sandbox')

options.add_argument('--start-maximized')

options.add_argument('--ignore-gpu-blocklist')

options.add_argument('--single-process')

options.add_argument('--disable-dev-shm-usage')

options.add_argument("--headless=new")

options.add_argument(f"user-agent={USER}")

options.add_argument("--incognito")

options.add_argument('--disable-blink-features=AutomationControlled')

options.add_experimental_option('useAutomationExtension', False)

options.add_experimental_option("excludeSwitches", ["enable-automation"])

options.add_argument("--log-level=3")

options.add_argument('--disable-extensions')

options.set_capability('pageLoadStrategy', 'none')

chrome_service = Service()
# chrome_service.creation_flags = CREATE_NO_WINDOW

while True:
    try:
        browser = webdriver.Chrome(service=chrome_service, options=options)

        browser.command_executor._commands["SEND_COMMAND"] = (
            "POST", "/session/$sessionId/chromium/send_command"
        )
        
        break

    except:pass

url = "https://magiceden.io/marketplace/8baMUdLZ5bsoNvpALp9NkWFW5or6RJQJTdAKWScbwW16"

browser.get(url)

# %%
browser.get_cookies()
# Out:
# [{'domain': 'magiceden.io',
#   'expiry': 1699984434,
#   'httpOnly': False,
#   'name': '_dd_s',
#   'path': '/',
#   'sameSite': 'Strict',
#   'secure': False,
#   'value': 'logs=0&expire=1699984429520&rum=0'},
#  {'domain': '.magiceden.io',
#   'expiry': 1723313523,
#   'httpOnly': False,
#   'name': 'intercom-device-id-htawnd0o',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'b622d115-7db5-426a-b0d5-d2035cfd0079'},
#  {'domain': '.magiceden.io',
#   'expiry': 1700588320,
#   'httpOnly': False,
#   'name': 'intercom-session-htawnd0o',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': ''},
#  {'domain': '.magiceden.io',
#   'expiry': 1723313520,
#   'httpOnly': False,
#   'name': 'intercom-id-htawnd0o',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'eb00d2f6-7da3-44c8-be1e-9d541ad0e32e'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519519,
#   'httpOnly': False,
#   'name': 'rl_session',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX1%2B6d1voPbNDLX1%2FDHl30XFwOX5DkfF05PLsTck5bMoZAEqJCBlaDRIfxGgM5GuCEAIx91aXN0gdGU7ens3LC6d3U6pJVOmf0ln3sOnKmZlJr0wuMSSl9cI76p%2FVhjMJMZ4xZg1arHyx4Q%3D%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_page_init_referring_domain',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX1%2FPDi7zmCiOWikYEoXd5rxzCaNbX3oIj4g%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_anonymous_id',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX19mV2xzNh4SmfywXu2vs28rdgx%2Bs4k4RoPdOSFjjylYQkr%2F%2BKvDj0iPtb2gdy3RJNY0g2fKQCKzWg%3D%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519515,
#   'httpOnly': True,
#   'name': 'cf_clearance',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'Xd4jMHAsLfA3QYoMyb9wVzOMGuC_YIQXwguZHzuEHk4-1699983515-0-1-48fc9831.4a9833a9.6baf3aa3-0.1.1699983515'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_group_trait',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX1%2BugWMvkFMCZuGaHLyD6N%2Fc12ja2OxOC9A%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1734543518,
#   'httpOnly': False,
#   'name': 'rs_ga_8BCG117VGT',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'GS1.1.1699983514978.1.0.1699983518.60.0.0'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_group_id',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX19X0dULNDL2W9IcLlLv6F2hi9KHVv0O6QE%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1734543518,
#   'httpOnly': False,
#   'name': 'rs_ga',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'GA1.1.459d13d4-d668-4bbf-b5be-377f0d8e6828'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519518,
#   'httpOnly': False,
#   'name': 'datadome',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'zloWqFmNawANB9e0rj9sQ9bhY10f8mKPjhEQJmP5pbRlWRWSxA8fRLCbXItJGBiUZWIDbQboHHLhX1rIaQ5pwpd2nycU4Q4tZJ6RG49apZjnh9APueCtK6nq8vI85wBT'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_trait',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX1%2Bn8NHes%2BsT0hpKyj8%2F6sN3MtHLvPST2S4%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_page_init_referrer',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX18yOglnuLfYfObYFhWmfKj88x9AWryeX9o%3D'},
#  {'domain': '.magiceden.io',
#   'httpOnly': True,
#   'name': '_cfuvid',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'GkoLqpazyXVjqXqP2GH1w0ARGsdDJk8m1vuHWFIi4G4-1699983509511-0-604800000'},
#  {'domain': '.magiceden.io',
#   'expiry': 1731519514,
#   'httpOnly': False,
#   'name': 'rl_user_id',
#   'path': '/',
#   'sameSite': 'Lax',
#   'secure': False,
#   'value': 'RudderEncrypt%3AU2FsdGVkX1%2BnWjdykxt8DJjo47mOmh1Fi2eXKqzwNxM%3D'},
#  {'domain': '.magiceden.io',
#   'expiry': 1699985309,
#   'httpOnly': True,
#   'name': '__cf_bm',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': '8.x2VxUSYih4wahQEBSwxGlKRqe0tg7ItLi4A_hd.Sw-1699983509-0-AYNQt3RhLWPlgU9cVbP/S3d4uiE/nN1PbMXDg5Q+JFQL/Oc2f5VRxZT6FsPmbUHCEcVUOr3qgQr36u2CPHAgHts='}]

# %%
session = requests.Session()

# %%
HEADERS = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "en-US,en;q=0.9",
    # "Accept-Encoding": "gzip, deflate, br",
    "Cache-Control": "no-cache",
    "Denorm-Nft-Shadow-Mode": "V2_ONLY",
    "Dnt": "1",
    # "Cookie": "_gcl_au=1.1.126805771.1697098973; rl_page_init_referrer=RudderEncrypt%3AU2FsdGVkX19j4wJhl9peXEDuUoiag%2BOUBksdVEwmIWiLnkJsxqwfCjO6LaPXmPq7; rl_page_init_referring_domain=RudderEncrypt%3AU2FsdGVkX1%2BwOneYRW1nQrs%2FI0BWYsd%2Fro%2BnJzGdhx4q9S4MlHVcmHhbjT4tzY%2F2; intercom-id-htawnd0o=6d1039a8-c09c-4fa8-912a-723870576644; intercom-device-id-htawnd0o=6d6464db-88a0-43f3-9dff-c2e84059dc21; rs_ga=GA1.1.14c34a5c-809c-4c31-b7d9-4fc2d1bcc1b3; _ga=GA1.2.822277618.1697111959; _ga_17CW5DWKSH=GS1.2.1697116309.2.0.1697116309.60.0.0; _cfuvid=ilb3cQ53Xa9uyOKAlC0hK2dHN3DLeboh9TL.3Uxci2U-1699975417754-0-604800000; arp_scroll_position=0; intercom-session-htawnd0o=; rs_ga_8BCG117VGT=GS1.1.1699975506725.6.0.1699976173.59.0.0; cf_clearance=Hw0V8be_HlrjQ_A17Z_VNammvx5QmqsFh6fZZYSrZGw-1699977651-0-1-48fc9831.4a9833a9.6baf3aa3-0.2.1699977651; rl_user_id=RudderEncrypt%3AU2FsdGVkX1%2Bzdd0NlMYKG3%2BrggeKNApeZNZ%2BBPBHAtU%3D; rl_trait=RudderEncrypt%3AU2FsdGVkX1%2BssBMUtK5vPLDMo%2F9VLWRcbYBWNXYY8%2FA%3D; rl_group_id=RudderEncrypt%3AU2FsdGVkX1%2FR%2B47%2FQz%2BRv0B6cW1pVyOY7uoC17bnLnc%3D; rl_group_trait=RudderEncrypt%3AU2FsdGVkX1%2FI51X80eoit%2F9cOosSTp2St3Q4gDoDe7I%3D; rl_anonymous_id=RudderEncrypt%3AU2FsdGVkX1%2BmZR%2FkMmtYoSvCYMUgZC5eQF5AqFxe8JaLDS%2Bw5b8ZBKMi0NjY7rfYJzjQumsL05S0c6Q6m%2B2L8w%3D%3D; datadome=3ORYelygjbAv5sg12ah~LRlNkMB2QwOjXhHyIFmzMHjI7JVP2TBuOkI4VAvIJngjZEHdLtNPWejVDoAX4xRCNwWxx~o~iKB4Tw6tXNOyUIMxqLxv84h8yIniF3bA~p_U; rl_session=RudderEncrypt%3AU2FsdGVkX19OLrD0l3LVkm%2F3nPSn9N%2B9dkd0ruE2NIBnu2dxbwue6bns%2FXelNmRcIibTcwhK7Tc9QxMmi2L0B1TW8F3P9DIBDh5jkfuv0ytb7MfDGT1DVqBlMB0EkCT0UKA1fO3hyC6Q3zaZyy%2Bzog%3D%3D; __cf_bm=jsBXLhxCurOUIEv3BfKKaSMrtXcT3yJ6vW7SskJ6RvY-1699982158-0-ARNge3aJF5hQVwyk1gRjKjJQvPiezCDmYyND3AGpk917iUxYhWGPi7YD42eIl9zJzZkrjc1s2HwJm1DgZCy/B/E=",
    "Origin": "https://magiceden.io",
    "Pragma": "no-cache",
    "Referer": "https://magiceden.io/",
    "Sec-Ch-Ua": '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Linux"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

# %%
for cookie in browser.get_cookies():
    session.cookies.set(cookie["name"], 
                        cookie["value"], 
                        domain=cookie["domain"], 
                        expires=cookie["expiry"],
                        # sameSite=cookie['sameSite'],
                        # httpOnly=cookie['httpOnly'],
                        secure=cookie['secure'])

# %%
session.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='__cf_bm', value='8.x2VxUSYih4wahQEBSwxGlKRqe0tg7ItLi4A_hd.Sw-1699983509-0-AYNQt3RhLWPlgU9cVbP/S3d4uiE/nN1PbMXDg5Q+JFQL/Oc2f5VRxZT6FsPmbUHCEcVUOr3qgQr36u2CPHAgHts=', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='_cfuvid', value='GkoLqpazyXVjqXqP2GH1w0ARGsdDJk8m1vuHWFIi4G4-1699983509511-0-604800000', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='cf_clearance', value='Xd4jMHAsLfA3QYoMyb9wVzOMGuC_YIQXwguZHzuEHk4-1699983515-0-1-48fc9831.4a9833a9.6baf3aa3-0.1.1699983515', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='datadome', value='zloWqFmNawANB9e0rj9sQ9bhY10f8mKPjhEQJmP5pbRlWRWSxA8fRLCbXItJGBiUZWIDbQboHHLhX1rIaQ5pwpd2nycU4Q4tZJ6RG49apZjnh9APueCtK6nq8vI85wBT', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='intercom-device-id-htawnd0o', value='b622d115-7db5-426a-b0d5-d2035cfd0079', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='intercom-id-htawnd0o', value='eb00d2f6-7da3-44c8-be1e-9d541ad0e32e', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='intercom-session-htawnd0o', value='', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='rl_anonymous_id', value='RudderEncrypt%3AU2FsdGVkX19mV2xzNh4SmfywXu2vs28rdgx%2Bs4k4RoPdOSFjjylYQkr%2F%2BKvDj0iPtb2gdy3RJNY0g2fKQCKzWg%3D%3D', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='rl_group_id', value='RudderEncrypt%3AU2FsdGVkX19X0dULNDL2W9IcLlLv6F2hi9KHVv0O6QE%3D', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='rl_group_trait', value='RudderEncrypt%3AU2FsdGVkX1%2BugWMvkFMCZuGaHLyD6N%2Fc12ja2OxOC9A%3D', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='rl_page_init_referrer', value='RudderEncrypt%3AU2FsdGVkX18yOglnuLfYfObYFhWmfKj88x9AWryeX9o%3D', port=None, port_specified=False, domain='.magiceden.io', domain_specified=True, dom ...

# %%
PAYLOAD = {
    "collectionSymbol": "",
    "onChainCollectionAddress": "8baMUdLZ5bsoNvpALp9NkWFW5or6RJQJTdAKWScbwW16",
    "direction": 2,
    "field": 1,
    "limit": 40,
    "offset": 160,
    "agg": 3,
    "compressionMode": "both"
}

url = "https://api-mainnet.magiceden.io/idxv2/getAllNftsByCollectionSymbol"

response = session.get(url, headers=HEADERS, params=PAYLOAD)

# print(response.url)

print(response.status_code)

print(session.cookies)

if response.ok:
    import json

    with open("data1.json", "w") as file:
        json.dump(response.json(), file, indent=4)
# Out:
# 403
# <RequestsCookieJar[<Cookie __cf_bm=8.x2VxUSYih4wahQEBSwxGlKRqe0tg7ItLi4A_hd.Sw-1699983509-0-AYNQt3RhLWPlgU9cVbP/S3d4uiE/nN1PbMXDg5Q+JFQL/Oc2f5VRxZT6FsPmbUHCEcVUOr3qgQr36u2CPHAgHts= for .magiceden.io/>, <Cookie _cfuvid=GkoLqpazyXVjqXqP2GH1w0ARGsdDJk8m1vuHWFIi4G4-1699983509511-0-604800000 for .magiceden.io/>, <Cookie cf_clearance=Xd4jMHAsLfA3QYoMyb9wVzOMGuC_YIQXwguZHzuEHk4-1699983515-0-1-48fc9831.4a9833a9.6baf3aa3-0.1.1699983515 for .magiceden.io/>, <Cookie datadome=zloWqFmNawANB9e0rj9sQ9bhY10f8mKPjhEQJmP5pbRlWRWSxA8fRLCbXItJGBiUZWIDbQboHHLhX1rIaQ5pwpd2nycU4Q4tZJ6RG49apZjnh9APueCtK6nq8vI85wBT for .magiceden.io/>, <Cookie intercom-device-id-htawnd0o=b622d115-7db5-426a-b0d5-d2035cfd0079 for .magiceden.io/>, <Cookie intercom-id-htawnd0o=eb00d2f6-7da3-44c8-be1e-9d541ad0e32e for .magiceden.io/>, <Cookie intercom-session-htawnd0o= for .magiceden.io/>, <Cookie rl_anonymous_id=RudderEncrypt%3AU2FsdGVkX19mV2xzNh4SmfywXu2vs28rdgx%2Bs4k4RoPdOSFjjylYQkr%2F%2BKvDj0iPtb2gdy3RJNY0g2fKQCKzWg%3D%3D for .magiceden.io/>, <Cookie rl_group_id=RudderEncrypt%3AU2FsdGVkX19X0dULNDL2W9IcLlLv6F2hi9KHVv0O6QE%3D for .magiceden.io/>, <Cookie rl_group_trait=RudderEncrypt%3AU2FsdGVkX1%2BugWMvkFMCZuGaHLyD6N%2Fc12ja2OxOC9A%3D for .magiceden.io/>, <Cookie rl_page_init_referrer=RudderEncrypt%3AU2FsdGVkX18yOglnuLfYfObYFhWmfKj88x9AWryeX9o%3D for .magiceden.io/>, <Cookie rl_page_init_referring_domain=RudderEncrypt%3AU2FsdGVkX1%2FPDi7zmCiOWikYEoXd5rxzCaNbX3oIj4g%3D for .magiceden.io/>, <Cookie rl_session=RudderEncrypt%3AU2FsdGVkX1%2B6d1voPbNDLX1%2FDHl30XFwOX5DkfF05PLsTck5bMoZAEqJCBlaDRIfxGgM5GuCEAIx91aXN0gdGU7ens3LC6d3U6pJVOmf0ln3sOnKmZlJr0wuMSSl9cI76p%2FVhjMJMZ4xZg1arHyx4Q%3D%3D for .magiceden.io/>, <Cookie rl_trait=RudderEncrypt%3AU2FsdGVkX1%2Bn8NHes%2BsT0hpKyj8%2F6sN3MtHLvPST2S4%3D for .magiceden.io/>, <Cookie rl_user_id=RudderEncrypt%3AU2FsdGVkX1%2BnWjdykxt8DJjo47mOmh1Fi2eXKqzwNxM%3D for .magiceden.io/>, <Cookie rs_ga=GA1.1.459d13d4-d668-4bbf-b5be-377f0d8e6828 for .magiceden.io/>, <Cookie rs_ga_8BCG117VGT=GS1.1.1699983514978.1.0.1699983518.60.0.0 for .magiceden.io/>, <Cookie _dd_s=logs=0&expire=1699984774352&rum=0 for magiceden.io/>]>
